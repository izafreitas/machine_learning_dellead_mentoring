# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ##**Conectando ao Google Drive para usar o dataset**

# %%
from google.colab import drive 
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ##**Lendo o dataset**

# %%
data= pd.read_csv('/content/drive/My Drive/Datasets/data_obesity.csv', sep=',', encoding= 'utf-8', decimal=';')

# %%
data.head()
# Out:
#     Unnamed: 0  ...                                             1975.2
# 0          NaN  ...  Prevalence of obesity among adults, BMI &Great...
# 1          NaN  ...                                         18+  years
# 2      Country  ...                                             Female
# 3  Afghanistan  ...                                      0.8 [0.2-2.0]
# 4      Albania  ...                                     8.6 [3.9-15.4]
#
# [5 rows x 127 columns]

# %% [markdown]
# ##**Verificando as colunas do dataset**

# %%
data.columns
# Out:
# Index(['Unnamed: 0', '2016', '2016.1', '2016.2', '2015', '2015.1', '2015.2',
#        '2014', '2014.1', '2014.2',
#        ...
#        '1978.2', '1977', '1977.1', '1977.2', '1976', '1976.1', '1976.2',
#        '1975', '1975.1', '1975.2'],
#       dtype='object', length=127)

# %% [markdown]
# ##**Verificando como o tipo dos dados está sendo identificado pelo pandas**

# %%
data.dtypes
# Out:
# Unnamed: 0    object
# 2016          object
# 2016.1        object
# 2016.2        object
# 2015          object
#                ...
# 1976.1        object
# 1976.2        object
# 1975          object
# 1975.1        object
# 1975.2        object
# Length: 127, dtype: object

# %%
data.duplicated().value_counts()
# Out:
# False    198
# dtype: int64

# %% [markdown]
# ##**Informações sobre o datset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Columns: 127 entries, Unnamed: 0 to 1975.2
# dtypes: object(127)
# memory usage: 196.6+ KB

# %% [markdown]
# ##**Mostrando estatísticas dos dados**

# %%
data.describe()
# Out:
#        Unnamed: 0     2016   2016.1  ...           1975         1975.1   1975.2
# count         196      198      198  ...            198            198      198
# unique        196      192      195  ...            177            155      185
# top          Fiji  No data  No data  ...  0.5 [0.2-1.1]  0.4 [0.1-1.2]  No data
# freq            1        4        4  ...              4              7        4
#
# [4 rows x 127 columns]

# %% [markdown]
# ## **Verificar se há valores duplicados**

# %%
duplicados = data[data.duplicated(keep='first')] 
print(duplicados)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 2016, 2016.1, 2016.2, 2015, 2015.1, 2015.2, 2014, 2014.1, 2014.2, 2013, 2013.1, 2013.2, 2012, 2012.1, 2012.2, 2011, 2011.1, 2011.2, 2010, 2010.1, 2010.2, 2009, 2009.1, 2009.2, 2008, 2008.1, 2008.2, 2007, 2007.1, 2007.2, 2006, 2006.1, 2006.2, 2005, 2005.1, 2005.2, 2004, 2004.1, 2004.2, 2003, 2003.1, 2003.2, 2002, 2002.1, 2002.2, 2001, 2001.1, 2001.2, 2000, 2000.1, 2000.2, 1999, 1999.1, 1999.2, 1998, 1998.1, 1998.2, 1997, 1997.1, 1997.2, 1996, 1996.1, 1996.2, 1995, 1995.1, 1995.2, 1994, 1994.1, 1994.2, 1993, 1993.1, 1993.2, 1992, 1992.1, 1992.2, 1991, 1991.1, 1991.2, 1990, 1990.1, 1990.2, 1989, 1989.1, 1989.2, 1988, 1988.1, 1988.2, 1987, 1987.1, 1987.2, 1986, 1986.1, 1986.2, 1985, 1985.1, 1985.2, 1984, 1984.1, 1984.2, ...]
# Index: []
#
# [0 rows x 127 columns]

# %% [markdown]
# ## **Removendo valores duplicados, se necessário**

# %%
df.drop_duplicates(keep='first', inplace=True) 
df.head()
# Out:
#     Unnamed: 0  ...                                             1975.2
# 0          NaN  ...  Prevalence of obesity among adults, BMI &Great...
# 1          NaN  ...                                         18+  years
# 2      Country  ...                                             Female
# 3  Afghanistan  ...                                      0.8 [0.2-2.0]
# 4      Albania  ...                                     8.6 [3.9-15.4]
#
# [5 rows x 127 columns]

# %% [markdown]
# ##**Função para remover incossistências**

# %%
#def remove_caracteres (DataFrame, columns, what):          #ainda por finalizar
    #for col in columns:
        #DataFrame[col] = DataFrame[col].str.strip()
 
#remove_caracteres(df, ['', ''], '[]')
#remove_caracteres(df, ['', ''], '-')

#df


#x = csv.strip("[] - ")
# Out:
#   File "<ipython-input-109-b73cdd3ca435>", line 2
#     for col in columns:
#     ^
# IndentationError: unexpected indent

# %%
type(np.nan)
# Out:
# float

# %% [markdown]
# ##**Substituindo os valores faltantes com NaN**
# Obs: Este passo deve ser feito depois que o dataset estiver organizado corretamente em linhas e colunas fazer depois que o df tiver tratado

# %%
data = data.head(20)
data = data.replace(['No data'], np.nan) #substituindo em todo o df os campos 'No data' por 'NaN'.
data.head()
# Out:
#                                                            0   ...                19
# Unnamed: 0                                                NaN  ...           Belgium
# 2016        Prevalence of obesity among adults, BMI &Great...  ...  22.1 [18.6-25.7]
# 2016.1      Prevalence of obesity among adults, BMI &Great...  ...  23.1 [18.0-28.6]
# 2016.2      Prevalence of obesity among adults, BMI &Great...  ...  21.0 [16.1-26.1]
# 2015        Prevalence of obesity among adults, BMI &Great...  ...  21.7 [18.4-25.2]
#
# [5 rows x 20 columns]

# %% [markdown]
# ##**Informações sobre o índice**

# %%
data.index
# Out:
# Index(['Unnamed: 0', '2016', '2016.1', '2016.2', '2015', '2015.1', '2015.2',
#        '2014', '2014.1', '2014.2', '2013', '2013.1', '2013.2', '2012',
#        '2012.1', '2012.2', '2011', '2011.1', '2011.2', '2010'],
#       dtype='object')

# %% [markdown]
# ## **Contando dados não nulos**

# %%
data.count()
# Out:
# 0     19
# 1     19
# 2     20
# 3     20
# 4     20
# 5     20
# 6     20
# 7     20
# 8     20
# 9     20
# 10    20
# 11    20
# 12    20
# 13    20
# 14    20
# 15    20
# 16    20
# 17    20
# 18    20
# 19    20
# dtype: int64

# %% [markdown]
# ## **Removendo a linha que contem +18**

# %%
data.drop([1,0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-062a59069b31> in <module>()
# ----> 1 data.drop([1,0])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %% [markdown]
# **Transpondo o DataFrame**

# %%
 data = data.T #para que serve?

# %% [markdown]
# ##**Criando a coluna 'ano'**

# %%
data['Ano'] = 0
data.head()
# Out:
#     Unnamed: 0                                               2016  ... Sexo Ano
# 0          NaN  Prevalence of obesity among adults, BMI &Great...  ...    0   0
# 1          NaN                                         18+  years  ...    0   0
# 2      Country                                         Both sexes  ...    0   0
# 3  Afghanistan                                      5.5 [3.4-8.1]  ...    0   0
# 4      Albania                                   21.7 [17.0-26.7]  ...    0   0
#
# [5 rows x 129 columns]

# %% [markdown]
# **Criando a coluna 'sexo'**

# %%
data['Sexo'] = 0
data.head()
# Out:
#                                                             0  ... Sexo
# Unnamed: 0                                                NaN  ...    0
# 2016        Prevalence of obesity among adults, BMI &Great...  ...    0
# 2016.1      Prevalence of obesity among adults, BMI &Great...  ...    0
# 2016.2      Prevalence of obesity among adults, BMI &Great...  ...    0
# 2015        Prevalence of obesity among adults, BMI &Great...  ...    0
#
# [5 rows x 21 columns]

# %%
del data['Ano']
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ano'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-2614e000fd76> in <module>()
# ----> 1 del data['Ano']
# ...

# %% [markdown]
# **Selecionando a primeira linha do df**

# %%
data.loc[0]
# Out:
# Unnamed: 0                                                  NaN
# 2016          Prevalence of obesity among adults, BMI &Great...
# 2016.1        Prevalence of obesity among adults, BMI &Great...
# 2016.2        Prevalence of obesity among adults, BMI &Great...
# 2015          Prevalence of obesity among adults, BMI &Great...
#                                     ...
# 1976.2        Prevalence of obesity among adults, BMI &Great...
# 1975          Prevalence of obesity among adults, BMI &Great...
# 1975.1        Prevalence of obesity among adults, BMI &Great...
# 1975.2        Prevalence of obesity among adults, BMI &Great...
# Ano                                                           0
# Name: 0, Length: 128, dtype: object

# %% [markdown]
# **Renomendo a primeira linha do DF**

# %%
#data.rename(columns={'Unnamed': 'Ano' }, inplace=True)
#data.head()

data.fill(99)
# Out:
#     Unnamed: 0                                               2016  ... Ano Sexo
# 0          NaN  Prevalence of obesity among adults, BMI &Great...  ...   0    0
# 1          NaN                                         18+  years  ...   0    0
# 2      Country                                         Both sexes  ...   0    0
# 3  Afghanistan                                      5.5 [3.4-8.1]  ...   0    0
# 4      Albania                                   21.7 [17.0-26.7]  ...   0    0
#
# [5 rows x 129 columns]

# %%
data = data.T
data.head()
# Out:
#                                                           0    ...               197
# Unnamed: 0                                                NaN  ...          Zimbabwe
# 2016        Prevalence of obesity among adults, BMI &Great...  ...  15.5 [12.0-19.2]
# 2016.1      Prevalence of obesity among adults, BMI &Great...  ...     4.7 [2.5-8.0]
# 2016.2      Prevalence of obesity among adults, BMI &Great...  ...  25.3 [19.1-32.0]
# 2015        Prevalence of obesity among adults, BMI &Great...  ...  15.2 [11.9-18.8]
#
# [5 rows x 198 columns]

# %%
data.columns
# Out:
# RangeIndex(start=0, stop=198, step=1)

# %%
data.melt(id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index=True)
# Out:
#          variable            value
# 0      Unnamed: 0              NaN
# 1      Unnamed: 0              NaN
# 2      Unnamed: 0          Country
# 3      Unnamed: 0      Afghanistan
# 4      Unnamed: 0          Albania
# ...           ...              ...
# 25141      1975.2  13.2 [7.1-20.7]
# 25142      1975.2    0.2 [0.1-0.5]
# 25143      1975.2    4.2 [1.5-8.9]
# 25144      1975.2    2.5 [1.0-5.1]
# 25145      1975.2   6.7 [3.0-12.2]
#
# [25146 rows x 2 columns]
